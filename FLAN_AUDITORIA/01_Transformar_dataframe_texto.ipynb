# %%
#02 Transformando o dataframe em texto
df = pd.read_csv(
    arquivo,
    sep=None,
    engine="python",
    encoding="utf-8",
    dtype=str
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #02 Transformando o dataframe em texto
# ----> 2 df = pd.read_csv(
#       3     arquivo,
#       4     sep=None,
#       5     engine="python",
#       6     encoding="utf-8",
#       7     dtype=str
#       8 )
#
# NameError: name 'pd' is not defined
